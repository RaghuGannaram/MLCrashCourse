# %%
print("Hello World..!")
# Out:
# Hello World..!

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 15)
y = np.sin(x)

plt.plot(x, y, marker='.')
plt.title("Sine Wave")
plt.xlabel("x (radians)")
plt.ylabel("sin(x)")
plt.grid()
